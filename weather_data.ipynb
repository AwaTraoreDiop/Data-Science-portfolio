# %%
import csv
import codecs
import urllib.request
import urllib.error
import sys

# %%
BaseURL = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'

# %%
ApiKey='6LUHRKDQ56UHGJKQXTKQTPQ5Z'
#UnitGroup sets the units of the output - us or metric
UnitGroup='metric'

# %%
#Location for the weather data
Location='France?'

# %%
#Optional start and end dates
#If nothing is specified, the forecast is retrieved. 
#If start date only is specified, a single historical or forecast day will be retrieved
#If both start and and end date are specified, a date range will be retrieved
StartDate = ''
EndDate=''

# %%
ContentType="json"

# %%
#include sections
#values include days,hours,current,alerts
Include="days"

# %% [markdown]
# download data

# %%
#basic query including location
ApiQuery=BaseURL + Location

# %%
#append the start and end date if present
if (len(StartDate)):
    ApiQuery+="/"+StartDate
    if (len(EndDate)):
        ApiQuery+="/"+EndDate

# %%
#Url is completed. Now add query parameters (could be passed as GET or POST)
ApiQuery+="?"

# %%
#append each parameter as necessary
if (len(UnitGroup)):
    ApiQuery+="&unitGroup="+UnitGroup

if (len(ContentType)):
    ApiQuery+="&contentType="+ContentType

if (len(Include)):
    ApiQuery+="&include="+Include

ApiQuery+="&key="+ApiKey # type: ignore

# %%
print(' - Running query URL: ', ApiQuery)
print()
# Out:
#  - Running query URL:  https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/France??&unitGroup=metric&contentType=json&include=days&key=6LUHRKDQ56UHGJKQXTKQTPQ5Z

# %%
try: 
    CSVBytes = urllib.request.urlopen(ApiQuery)
except urllib.error.HTTPError  as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except  urllib.error.URLError as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code,ErrorInfo)
    sys.exit()

# %%
# Parse the results as CSV
CSVText = csv.reader(codecs.iterdecode(CSVBytes, 'utf-8'))

# %%
RowIndex = 0

# The first row contain the headers and the additional rows each contain the weather metrics for a single day
# To simply our code, we use the knowledge that column 0 contains the location and column 1 contains the date.  The data starts at column 4
for Row in CSVText:
    if RowIndex == 0:
        firstRow = Row
    else:
        print('Weather in ', Row[0], ' on ', Row[1])

        ColIndex = 0
        for Col in Row:
            if ColIndex >= 4:
                print('   ', firstRow[ColIndex], ' = ', Row[ColIndex])
            ColIndex += 1
    RowIndex += 1
print(CSVText)
# Out:
# <_csv.reader object at 0x000001FD272E0340>

# %%
# If there are no CSV rows then something fundamental went wrong
if RowIndex == 0:
    print('Sorry, but it appears that there was an error connecting to the weather server.')
    print('Please check your network connection and try again..')

# If there is only one CSV  row then we likely got an error from the server
if RowIndex == 1:
    print('Sorry, but it appears that there was an error retrieving the weather data.')
    print('Error: ', firstRow)

print()
# Out:
# Sorry, but it appears that there was an error retrieving the weather data.
# Error:  ['{"queryCost":1', 'latitude:48.8572', 'longitude:2.34141', 'resolvedAddress:"France"', 'address:"France"', 'timezone:"Europe/Paris"', 'tzoffset:1.0', 'days:[{"datetime":"2023-03-20"', 'datetimeEpoch:1679266800', 'tempmax:13.9', 'tempmin:1.6', 'temp:8.2', 'feelslikemax:13.9', 'feelslikemin:0.1', 'feelslike:7.9', 'dew:4.2', 'humidity:77.1', 'precip:0.3', 'precipprob:0.0', 'precipcover:8.33', 'preciptype:["rain"]', 'snow:0.0', 'snowdepth:0.0', 'windgust:26.3', 'windspeed:14.8', 'winddir:212.8', 'pressure:1021.0', 'cloudcover:77.4', 'visibility:12.9', 'solarradiation:47.9', 'solarenergy:4.2', 'uvindex:2.0', 'severerisk:10.0', 'sunrise:"06:54:17"', 'sunriseEpoch:1679291657', 'sunset:"19:03:01"', 'sunsetEpoch:1679335381', 'moonphase:0.96', 'conditions:"Partially cloudy"', 'description:"Partly cloudy throughout the day."', 'icon:"partly-cloudy-day"', 'stations:["LFPV"', 'LFPO', 'C1292', 'LFPB]', 'source:"comb"}', '{"datetime":"2023-03-21"', 'datetimeEpoch:1679353200', 'tempmax:15.7', 'tempmin:7.7', 'temp:10.9', 'feelslikemax:15.7', 'feelslikemin:6.5', 'feelslike:10.4', 'dew:6.8', 'humidity:76.4', 'precip:0.3', 'precipprob:14.3', 'precipcover:8.33', 'preciptype:["rain"]', 'snow:0.0', 'snowdepth:0.0', 'windgust:41.4', 'windspeed:17.3', 'winddir:206.6', 'pressure:1015.4', 'cloudcover:87.6', 'visibility:24.1', 'solarradiation:104.4', 'solarenergy:9.0', 'uvindex:5.0', 'severerisk:10.0', 'sunrise:"06:52:11"', 'sunriseEpoch:1679377931', 'sunset:"19:04:32"', 'sunsetEpoch:1679421872', 'moonphase:0.0', 'conditions:"Partially cloudy"', 'description:"Partly cloudy throughout the day."', 'icon:"partly-cloudy-day"', 'stations:null', 'source:"fcst"}', '{"datetime":"2023-03-22"', 'datetimeEpoch:1679439600', 'tempmax:13.2', 'tempmin:7.9', 'temp:10.4', 'feelslikemax:13.2', 'feelslikemin:5.7', 'feelslike:9.5', 'dew:7.8', 'humidity:84.2', 'precip:1.1', 'precipprob:71.4', 'precipcover:25.0', 'preciptype:["rain"]', 'snow:0.0', 'snowdepth:0.0', 'windgust:46.1', 'windspeed:19.1', 'winddir:202.9', 'pressure:1010.0', 'cloudcover:95.0', 'visibility:21.2', 'solarradiation:15.5', 'solarenergy:1.3', 'uvindex:1.0', 'severerisk:10.0', 'sunrise:"06:50:04"', 'sunriseEpoch:1679464204', 'sunset:"19:06:02"', 'sunsetEpoch:1679508362', 'moonphase:0.02', 'conditions:"Rain', ' Overcast"', 'description:"Cloudy skies throughout the day with a chance of rain."', 'icon:"rain"', 'stations:null', 'source:"fcst"}', '{"datetime":"2023-03-23"', 'datetimeEpoch:1679526000', 'tempmax:15.1', 'tempmin:10.8', 'temp:12.4', 'feelslikemax:15.1', 'feelslikemin:10.8', 'feelslike:12.4', 'dew:8.7', 'humidity:78.5', 'precip:0.9', 'precipprob:81.0', 'precipcover:16.67', 'preciptype:["rain"]', 'snow:0.0', 'snowdepth:0.0', 'windgust:53.6', 'windspeed:19.1', 'winddir:210.0', 'pressure:1006.1', 'cloudcover:100.0', 'visibility:23.3', 'solarradiation:39.3', 'solarenergy:3.5', 'uvindex:2.0', 'severerisk:10.0', 'sunrise:"06:47:58"', 'sunriseEpoch:1679550478', 'sunset:"19:07:33"', 'sunsetEpoch:1679594853', 'moonphase:0.06', 'conditions:"Rain', ' Overcast"', 'description:"Cloudy skies throughout the day with a chance of rain."', 'icon:"rain"', 'stations:null', 'source:"fcst"}', '{"datetime":"2023-03-24"', 'datetimeEpoch:1679612400', 'tempmax:13.8', 'tempmin:10.0', 'temp:11.7', 'feelslikemax:13.8', 'feelslikemin:7.6', 'feelslike:11.6', 'dew:7.3', 'humidity:75.0', 'precip:3.0', 'precipprob:90.5', 'precipcover:16.67', 'preciptype:["rain"]', 'snow:0.0', 'snowdepth:0.0', 'windgust:73.1', 'windspeed:24.8', 'winddir:230.5', 'pressure:1006.9', 'cloudcover:68.0', 'visibility:22.6', 'solarradiation:139.8', 'solarenergy:12.0', 'uvindex:6.0', 'severerisk:10.0', 'sunrise:"06:45:52"', 'sunriseEpoch:1679636752', 'sunset:"19:09:04"', 'sunsetEpoch:1679681344', 'moonphase:0.09', 'conditions:"Rain', ' Partially cloudy"', 'description:"Partly cloudy throughout the day with rain."', 'icon:"rain"', 'stations:null', 'source:"fcst"}', '{"datetime":"2023-03-25"', 'datetimeEpoch:1679698800', 'tempmax:15.2', 'tempmin:7.9', ' ...
